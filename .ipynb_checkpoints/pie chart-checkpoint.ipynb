# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('owid-covid-data.xlsx', usecols='C:E')
df.rename(columns={'location':'국가','date':'일자', 'total_cases':'확진자'}, inplace=True)
df = df.fillna(0)
df['일자'] = pd.to_datetime(df['일자'])
df['일자'] = df['일자'].dt.strftime('%y.%m.%d')
df = df[df['일자'] == '22.03.28']
df['확진자'] = df['확진자'].astype(int)
df
# Out:
#                        국가        일자        확진자
# 763           Afghanistan  22.03.28     177602
# 1538               Africa  22.03.28   11501709
# 2301              Albania  22.03.28     273432
# 3064              Algeria  22.03.28     265641
# 3821              Andorra  22.03.28      39713
# ...                   ...       ...        ...
# 168819  Wallis and Futuna  22.03.28        454
# 169616              World  22.03.28  482325063
# 170334              Yemen  22.03.28      11803
# 171075             Zambia  22.03.28     316550
# 171814           Zimbabwe  22.03.28     245927
#
# [228 rows x 3 columns]

# %%
continents = ['Africa', 'Asia', 'Europe', 'European Union', 'High income', 'Upper middle income', 'Low income', 
              'Lower middle income', 'North America', 'South Africa', 'South America', 'World']
filt = df['국가'].isin(continents)
df = df[~filt]
df
# Out:
#                        국가        일자      확진자
# 763           Afghanistan  22.03.28   177602
# 2301              Albania  22.03.28   273432
# 3064              Algeria  22.03.28   265641
# 3821              Andorra  22.03.28    39713
# 4560               Angola  22.03.28    99115
# ...                   ...       ...      ...
# 168293            Vietnam  22.03.28  9274849
# 168819  Wallis and Futuna  22.03.28      454
# 170334              Yemen  22.03.28    11803
# 171075             Zambia  22.03.28   316550
# 171814           Zimbabwe  22.03.28   245927
#
# [216 rows x 3 columns]

# %%
df = df.sort_values(by=['확진자'], ascending=0)
df_top = df.head(10)
df_top
# Out:
#                     국가        일자       확진자
# 163208   United States  22.03.28  79995485
# 72669            India  22.03.28  43021982
# 22732           Brazil  22.03.28  29857641
# 56330           France  22.03.28  25111975
# 162411  United Kingdom  22.03.28  20971446
# 60117          Germany  22.03.28  19492672
# 128638          Russia  22.03.28  17525184
# 158239          Turkey  22.03.28  14815041
# 78794            Italy  22.03.28  14396283
# 144904     South Korea  22.03.28  12350428

# %%
df_etc = df.iloc[10:]
df_etc
# Out:
#                           국가        일자       확진자
# 146414                 Spain  22.03.28  11451676
# 168293               Vietnam  22.03.28   9274849
# 6855               Argentina  22.03.28   9028730
# 111010           Netherlands  22.03.28   7869196
# 74976                   Iran  22.03.28   7154003
# ...                      ...       ...       ...
# 94614                  Macao  22.03.28        82
# 166752               Vatican  22.03.28        29
# 99634       Marshall Islands  22.03.28         7
# 129951          Saint Helena  22.03.28         4
# 102370  Micronesia (country)  22.03.28         1
#
# [206 rows x 3 columns]

# %%
df_top.set_index('국가', inplace=True)

# %%
df_top.loc['ETC'] = ['22.03.28', df_etc['확진자'].sum()]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df_top
# Out:
#                       일자        확진자
# 국가
# United States   22.03.28   79995485
# India           22.03.28   43021982
# Brazil          22.03.28   29857641
# France          22.03.28   25111975
# United Kingdom  22.03.28   20971446
# Germany         22.03.28   19492672
# Russia          22.03.28   17525184
# Turkey          22.03.28   14815041
# Italy           22.03.28   14396283
# South Korea     22.03.28   12350428
# ETC             22.03.28  206352092

# %%
df_top.reset_index(inplace=True)
df_top
# Out:
#                 국가        일자        확진자
# 0    United States  22.03.28   79995485
# 1            India  22.03.28   43021982
# 2           Brazil  22.03.28   29857641
# 3           France  22.03.28   25111975
# 4   United Kingdom  22.03.28   20971446
# 5          Germany  22.03.28   19492672
# 6           Russia  22.03.28   17525184
# 7           Turkey  22.03.28   14815041
# 8            Italy  22.03.28   14396283
# 9      South Korea  22.03.28   12350428
# 10             ETC  22.03.28  206352092

# %%
fig = plt.figure(figsize=(8,8))
values = df_top['확진자'].tolist()
labels = df_top['국가'].tolist()
colors = ['#ff0000', '#ffa500', '#ffff00', '#9acd32', '#008000',
          '#00ffff', '#0000ff', '#4b0082', '#800080', '#ff00ff', '#808080']
plt.pie(values, labels=labels, wedgeprops=dict(width=0.5),
        autopct = '%.1f%%', startangle=180, colors=colors, pctdistance = 0.8)
plt.show()
