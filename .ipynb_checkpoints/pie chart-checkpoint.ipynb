# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('owid-covid-data.xlsx', usecols='C:E')
df.rename(columns={'location':'국가','date':'일자', 'total_cases':'확진자'}, inplace=True)
df = df.fillna(0)
df['일자'] = pd.to_datetime(df['일자'])
df['일자'] = df['일자'].dt.strftime('%y.%m.%d')
df = df[df['일자'] == '22.08.20']
df['확진자'] = df['확진자'].astype(int)
df
# Out:
#                        국가        일자        확진자
# 908           Afghanistan  22.08.20     190435
# 1828               Africa  22.08.20   12312240
# 2736              Albania  22.08.20     325736
# 3644              Algeria  22.08.20     269731
# 4546              Andorra  22.08.20      45975
# ...                   ...       ...        ...
# 206636  Wallis and Futuna  22.08.20        761
# 207579              World  22.08.20  595675655
# 208442              Yemen  22.08.20      11915
# 209328             Zambia  22.08.20     332264
# 210212           Zimbabwe  22.08.20     256616
#
# [229 rows x 3 columns]

# %%
continents = ['Africa', 'Asia', 'Europe', 'European Union', 'High income', 'Upper middle income', 'Low income', 
              'Lower middle income', 'North America', 'South Africa', 'South America', 'World']
filt = df['국가'].isin(continents)
df = df[~filt]
df
# Out:
#                        국가        일자       확진자
# 908           Afghanistan  22.08.20    190435
# 2736              Albania  22.08.20    325736
# 3644              Algeria  22.08.20    269731
# 4546              Andorra  22.08.20     45975
# 5430               Angola  22.08.20    102636
# ...                   ...       ...       ...
# 205965            Vietnam  22.08.20  11382258
# 206636  Wallis and Futuna  22.08.20       761
# 208442              Yemen  22.08.20     11915
# 209328             Zambia  22.08.20    332264
# 210212           Zimbabwe  22.08.20    256616
#
# [217 rows x 3 columns]

# %%
df = df.sort_values(by=['확진자'], ascending=0)
df_top = df.head(10)
df_top
# Out:
#                     국가        일자       확진자
# 199047   United States  22.08.20  93634408
# 87529            India  22.08.20  44339429
# 67205           France  22.08.20  34381962
# 27082           Brazil  22.08.20  34264237
# 71717          Germany  22.08.20  31808179
# 198105  United Kingdom  22.08.20  23549842
# 176509     South Korea  22.08.20  22240331
# 94814            Italy  22.08.20  21630998
# 156920          Russia  22.08.20  18800180
# 96649            Japan  22.08.20  16962177

# %%
df_etc = df.iloc[10:]
df_etc
# Out:
#                        국가        일자       확진자
# 192754             Turkey  22.08.20  16671848
# 178309              Spain  22.08.20  13314764
# 143860            Oceania  22.08.20  11984991
# 205965            Vietnam  22.08.20  11382258
# 11861           Australia  22.08.20   9911819
# ...                   ...       ...       ...
# 206636  Wallis and Futuna  22.08.20       761
# 89357       International  22.08.20       721
# 204134            Vatican  22.08.20        29
# 158523       Saint Helena  22.08.20         4
# 140179        North Korea  22.08.20         1
#
# [207 rows x 3 columns]

# %%
df_top.set_index('국가', inplace=True)

# %%
df_top.loc['ETC'] = ['22.08.20', df_etc['확진자'].sum()]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df_top
# Out:
#                       일자        확진자
# 국가
# United States   22.08.20   93634408
# India           22.08.20   44339429
# France          22.08.20   34381962
# Brazil          22.08.20   34264237
# Germany         22.08.20   31808179
# United Kingdom  22.08.20   23549842
# South Korea     22.08.20   22240331
# Italy           22.08.20   21630998
# Russia          22.08.20   18800180
# Japan           22.08.20   16962177
# ETC             22.08.20  262039173

# %%
df_top.reset_index(inplace=True)
df_top
# Out:
#                 국가        일자        확진자
# 0    United States  22.08.20   93634408
# 1            India  22.08.20   44339429
# 2           France  22.08.20   34381962
# 3           Brazil  22.08.20   34264237
# 4          Germany  22.08.20   31808179
# 5   United Kingdom  22.08.20   23549842
# 6      South Korea  22.08.20   22240331
# 7            Italy  22.08.20   21630998
# 8           Russia  22.08.20   18800180
# 9            Japan  22.08.20   16962177
# 10             ETC  22.08.20  262039173

# %%
fig = plt.figure(figsize=(8,8))
values = df_top['확진자'].tolist()
labels = df_top['국가'].tolist()
colors = ['#ff0000', '#ffa500', '#ffff00', '#9acd32', '#008000',
          '#00ffff', '#0000ff', '#4b0082', '#800080', '#ff00ff', '#808080']
plt.pie(values, labels=labels, wedgeprops=dict(width=0.5),
        autopct = '%.1f%%', startangle=180, colors=colors, pctdistance = 0.8)
plt.show()
