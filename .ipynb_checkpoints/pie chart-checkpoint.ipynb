# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('owid-covid-data.xlsx', usecols='C:E')
df.rename(columns={'location':'국가','date':'일자', 'total_cases':'확진자'}, inplace=True)
df = df.fillna(0)
df['일자'] = pd.to_datetime(df['일자'])
df['일자'] = df['일자'].dt.strftime('%y.%m.%d')
df = df[df['일자'] == '22.08.14']
df['확진자'] = df['확진자'].astype(int)
df
# Out:
#                        국가        일자        확진자
# 902           Afghanistan  22.08.14     189045
# 1816               Africa  22.08.14   12293555
# 2718              Albania  22.08.14     321804
# 3620              Algeria  22.08.14     269141
# 4516              Andorra  22.08.14      45899
# ...                   ...       ...        ...
# 205245  Wallis and Futuna  22.08.14        761
# 206182              World  22.08.14  590331311
# 207039              Yemen  22.08.14      11903
# 207919             Zambia  22.08.14     331925
# 208797           Zimbabwe  22.08.14     256539
#
# [229 rows x 3 columns]

# %%
continents = ['Africa', 'Asia', 'Europe', 'European Union', 'High income', 'Upper middle income', 'Low income', 
              'Lower middle income', 'North America', 'South Africa', 'South America', 'World']
filt = df['국가'].isin(continents)
df = df[~filt]
df
# Out:
#                        국가        일자       확진자
# 902           Afghanistan  22.08.14    189045
# 2718              Albania  22.08.14    321804
# 3620              Algeria  22.08.14    269141
# 4516              Andorra  22.08.14     45899
# 5394               Angola  22.08.14    102636
# ...                   ...       ...       ...
# 204580            Vietnam  22.08.14  11365784
# 205245  Wallis and Futuna  22.08.14       761
# 207039              Yemen  22.08.14     11903
# 207919             Zambia  22.08.14    331925
# 208797           Zimbabwe  22.08.14    256539
#
# [217 rows x 3 columns]

# %%
df = df.sort_values(by=['확진자'], ascending=0)
df_top = df.head(10)
df_top
# Out:
#                     국가        일자       확진자
# 197704   United States  22.08.14  92927104
# 86953            India  22.08.14  44268381
# 66755           France  22.08.14  34253699
# 26902           Brazil  22.08.14  34148131
# 71237          Germany  22.08.14  31535340
# 196768  United Kingdom  22.08.14  23509727
# 94190            Italy  22.08.14  21499531
# 175344     South Korea  22.08.14  21418036
# 155887          Russia  22.08.14  18607284
# 191481          Turkey  22.08.14  16295817

# %%
df_etc = df.iloc[10:]
df_etc
# Out:
#                        국가        일자       확진자
# 96013               Japan  22.08.14  15656681
# 177132              Spain  22.08.14  13294139
# 142911            Oceania  22.08.14  11849200
# 204580            Vietnam  22.08.14  11365784
# 11783           Australia  22.08.14   9810496
# ...                   ...       ...       ...
# 205245  Wallis and Futuna  22.08.14       761
# 88769       International  22.08.14       721
# 202761            Vatican  22.08.14        29
# 157478       Saint Helena  22.08.14         4
# 139248        North Korea  22.08.14         1
#
# [207 rows x 3 columns]

# %%
df_top.set_index('국가', inplace=True)

# %%
df_top.loc['ETC'] = ['22.08.14', df_etc['확진자'].sum()]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df_top
# Out:
#                       일자        확진자
# 국가
# United States   22.08.14   92927104
# India           22.08.14   44268381
# France          22.08.14   34253699
# Brazil          22.08.14   34148131
# Germany         22.08.14   31535340
# United Kingdom  22.08.14   23509727
# Italy           22.08.14   21499531
# South Korea     22.08.14   21418036
# Russia          22.08.14   18607284
# Turkey          22.08.14   16295817
# ETC             22.08.14  259712906

# %%
df_top.reset_index(inplace=True)
df_top
# Out:
#                 국가        일자        확진자
# 0    United States  22.08.14   92927104
# 1            India  22.08.14   44268381
# 2           France  22.08.14   34253699
# 3           Brazil  22.08.14   34148131
# 4          Germany  22.08.14   31535340
# 5   United Kingdom  22.08.14   23509727
# 6            Italy  22.08.14   21499531
# 7      South Korea  22.08.14   21418036
# 8           Russia  22.08.14   18607284
# 9           Turkey  22.08.14   16295817
# 10             ETC  22.08.14  259712906

# %%
fig = plt.figure(figsize=(8,8))
values = df_top['확진자'].tolist()
labels = df_top['국가'].tolist()
colors = ['#ff0000', '#ffa500', '#ffff00', '#9acd32', '#008000',
          '#00ffff', '#0000ff', '#4b0082', '#800080', '#ff00ff', '#808080']
plt.pie(values, labels=labels, wedgeprops=dict(width=0.5),
        autopct = '%.1f%%', startangle=180, colors=colors, pctdistance = 0.8)
plt.show()
