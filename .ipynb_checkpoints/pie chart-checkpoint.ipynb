# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('owid-covid-data.xlsx', usecols='C:E')
df.rename(columns={'location':'국가','date':'일자', 'total_cases':'확진자'}, inplace=True)
df = df.fillna(0)
df['일자'] = pd.to_datetime(df['일자'])
df['일자'] = df['일자'].dt.strftime('%y.%m.%d')
df = df[df['일자'] == '22.03.31']
df['확진자'] = df['확진자'].astype(int)
df
# Out:
#                        국가        일자        확진자
# 766           Afghanistan  22.03.31     177747
# 1544               Africa  22.03.31   11558935
# 2310              Albania  22.03.31     273677
# 3076              Algeria  22.03.31     265671
# 3836              Andorra  22.03.31      40024
# ...                   ...       ...        ...
# 170247  Wallis and Futuna  22.03.31        454
# 171047              World  22.03.31  488436950
# 171768              Yemen  22.03.31      11806
# 172512             Zambia  22.03.31     316850
# 173254           Zimbabwe  22.03.31     246286
#
# [228 rows x 3 columns]

# %%
continents = ['Africa', 'Asia', 'Europe', 'European Union', 'High income', 'Upper middle income', 'Low income', 
              'Lower middle income', 'North America', 'South Africa', 'South America', 'World']
filt = df['국가'].isin(continents)
df = df[~filt]
df
# Out:
#                        국가        일자      확진자
# 766           Afghanistan  22.03.31   177747
# 2310              Albania  22.03.31   273677
# 3076              Algeria  22.03.31   265671
# 3836              Andorra  22.03.31    40024
# 4578               Angola  22.03.31    99169
# ...                   ...       ...      ...
# 169718            Vietnam  22.03.31  9564609
# 170247  Wallis and Futuna  22.03.31      454
# 171768              Yemen  22.03.31    11806
# 172512             Zambia  22.03.31   316850
# 173254           Zimbabwe  22.03.31   246286
#
# [216 rows x 3 columns]

# %%
df = df.sort_values(by=['확진자'], ascending=0)
df_top = df.head(10)
df_top
# Out:
#                     국가        일자       확진자
# 164612   United States  22.03.31  80103661
# 72957            India  22.03.31  43025775
# 22822           Brazil  22.03.31  29951670
# 56555           France  22.03.31  25668176
# 60357          Germany  22.03.31  21394747
# 163812  United Kingdom  22.03.31  21216038
# 129904          Russia  22.03.31  17583111
# 159625          Turkey  22.03.31  14860560
# 79106            Italy  22.03.31  14642354
# 146236     South Korea  22.03.31  13375818

# %%
df_etc = df.iloc[10:]
df_etc
# Out:
#                           국가        일자       확진자
# 147752                 Spain  22.03.31  11508309
# 169718               Vietnam  22.03.31   9564609
# 6882               Argentina  22.03.31   9037911
# 111451           Netherlands  22.03.31   7953120
# 75273                   Iran  22.03.31   7162220
# ...                      ...       ...       ...
# 94989                  Macao  22.03.31        82
# 168171               Vatican  22.03.31        29
# 100030      Marshall Islands  22.03.31         7
# 131223          Saint Helena  22.03.31         4
# 102778  Micronesia (country)  22.03.31         1
#
# [206 rows x 3 columns]

# %%
df_top.set_index('국가', inplace=True)

# %%
df_top.loc['ETC'] = ['22.03.31', df_etc['확진자'].sum()]
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df_top
# Out:
#                       일자        확진자
# 국가
# United States   22.03.31   80103661
# India           22.03.31   43025775
# Brazil          22.03.31   29951670
# France          22.03.31   25668176
# Germany         22.03.31   21394747
# United Kingdom  22.03.31   21216038
# Russia          22.03.31   17583111
# Turkey          22.03.31   14860560
# Italy           22.03.31   14642354
# South Korea     22.03.31   13375818
# ETC             22.03.31  208414581

# %%
df_top.reset_index(inplace=True)
df_top
# Out:
#                 국가        일자        확진자
# 0    United States  22.03.31   80103661
# 1            India  22.03.31   43025775
# 2           Brazil  22.03.31   29951670
# 3           France  22.03.31   25668176
# 4          Germany  22.03.31   21394747
# 5   United Kingdom  22.03.31   21216038
# 6           Russia  22.03.31   17583111
# 7           Turkey  22.03.31   14860560
# 8            Italy  22.03.31   14642354
# 9      South Korea  22.03.31   13375818
# 10             ETC  22.03.31  208414581

# %%
fig = plt.figure(figsize=(8,8))
values = df_top['확진자'].tolist()
labels = df_top['국가'].tolist()
colors = ['#ff0000', '#ffa500', '#ffff00', '#9acd32', '#008000',
          '#00ffff', '#0000ff', '#4b0082', '#800080', '#ff00ff', '#808080']
plt.pie(values, labels=labels, wedgeprops=dict(width=0.5),
        autopct = '%.1f%%', startangle=180, colors=colors, pctdistance = 0.8)
plt.show()
